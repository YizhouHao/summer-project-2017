# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../data/data-table-2017-06-22T20:29.csv')
featureList=df['Features'].tolist()

# %%
from textblob import TextBlob
blobList=map(TextBlob, featureList)
tags=[b.tags for b in blobList]
print(tags)
# Out:
# [[('FLEXIBLE', 'NNP'), ('Resin', 'NNP'), ('top', 'JJ'), ('allows', 'NNS'), ('for', 'IN'), ('indoor', 'NN'), ('and', 'CC'), ('light', 'JJ'), ('outdoor', 'NN'), ('use', 'NN'), ('LIGHTWEIGHT', 'NNP'), ('Easy', 'NNP'), ('to', 'TO'), ('carry', 'VB'), ('NON-MARRING', 'NNP'), ('Let', 'VB'), ('tips', 'NNS'), ('protect', 'VB'), ('floor', 'NN'), ('surfaces', 'NNS'), ('FOLDS', 'NNP'), ('FLAT', 'NNP'), ('Just', 'RB'), ('1.5', 'CD'), ('Inch', 'JJ'), ('wide', 'JJ'), ('for', 'IN'), ('easy', 'JJ'), ('storage', 'NN'), ('Easy', 'NNP'), ('to', 'TO'), ('Clean', 'VB')], [('Altra', 'NNP'), ('Owen', 'NNP'), ('Retro', 'NNP'), ('Desk', 'NNP'), ('creates', 'VBZ'), ('usable', 'JJ'), ('space', 'NN'), ('even', 'RB'), ('in', 'IN'), ('small', 'JJ'), ('rooms', 'NNS'), ('The', 'DT'), ('slim', 'NN'), ('profile', 'NN'), ('is', 'VBZ'), ('not', 'RB'), ('only', 'RB'), ('perfectly', 'RB'), ('sized', 'VBN'), ('for', 'IN'), ('a', 'DT'), ('desk', 'NN'), ('but', 'CC'), ('this', 'DT'), ('versatile', 'JJ'), ('piece', 'NN'), ('can', 'MD'), ('also', 'RB'), ('be', 'VB'), ('used', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('vanity', 'NN'), ('or', 'CC'), ('console', 'NN'), ('table', 'NN'), ('Desk', 'NNP'), ('is', 'VBZ'), ('simple', 'JJ'), ('to', 'TO'), ('assemble', 'JJ'), ('just', 'RB'), ('attach', 'VBP'), ('the', 'DT'), ('4', 'CD'), ('legs', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('desk', 'NN'), ('top', 'NN'), ('Metal', 'NNP'), ('hairpin-style', 'JJ'), ('legs', 'NN'), ('create', 'VB'), ('a', 'DT'), ('throwback', 'NN'), ('to', 'TO'), ('popular', 'JJ'), ('mid-century', 'NN'), ('designs', 'NNS'), ('for', 'IN'), ('a', 'DT'), ('fun', 'NN'), ('retro', 'NN'), ('industrial', 'JJ'), ('feel', 'NN'), ('Sonoma', 'NNP'), ('Oak', 'NNP'), ('table', 'JJ'), ('top', 'NN'), ('and', 'CC'), ('Gunmetal', 'NNP'), ('Gray', 'NNP'), ('legs', 'VBD'), ('bring', 'VBG'), ('an', 'DT'), ('updated', 'JJ'), ('style', 'NN'), ('to', 'TO'), ('your', 'PRP$'), ('décor', 'NN')], [('The', 'DT'), ('Perfect', 'NNP'), ('Little', 'NNP'), ('End', 'NNP'), ('Table', 'NNP'), ('for', 'IN'), ('finishing', 'VBG'), ('touches', 'NNS'), ('Super-light', 'NNP'), ('Hollowcore', 'NNP'), ('Contruction', 'NNP'), ('Durable', 'NNP'), ('wood', 'NN'), ('grain', 'NN'), ('finish', 'NN'), ('is', 'VBZ'), ('easy', 'JJ'), ('to', 'TO'), ('clean', 'VB'), ('For', 'IN'), ('College', 'NNP'), ('Dorms', 'NNP'), ('Guest', 'NNP'), ('Rooms', 'NNP'), ('or', 'CC'), ('Any', 'NNP'), ('Room', 'NNP'), ('Easy', 'NNP'), ('to', 'TO'), ('assemble', 'VB'), ('No', 'NNP'), ('need', 'NN'), ('to', 'TO'), ('shop', 'VB'), ('delivered', 'VBN'), ('to', 'TO'), ('your', 'PRP$'), ('home', 'NN'), ('This', 'DT'), ('item', 'NN'), ('is', 'VBZ'), ('eligible', 'JJ'), ('for', 'IN'), ('free', 'JJ'), ('replacement', 'NN'), ('parts', 'NNS'), ('Contact', 'NNP'), ('Amazon', 'NNP'), ('Customer', 'NNP'), ('Service', 'NNP'), ('for', 'IN'), ('more', 'JJR'), ('information', 'NN')], [('Simple', 'JJ'), ('stylish', 'JJ'), ('design', 'NN'), ('yet', 'RB'), ('functional', 'JJ'), ('and', 'CC'), ('suitable', 'JJ'), ('for', 'IN'), ('any', 'DT'), ('room', 'NN'), ('that', 'WDT'), ('has', 'VBZ'), ('limited', 'VBN'), ('space', 'NN'), ('for', 'IN'), ('a', 'DT'), ('computer', 'NN'), ('Material', 'NN'), ('Manufactured', 'VBN'), ('from', 'IN'), ('Engineered', 'NNP'), ('particle', 'NN'), ('board', 'NN'), ('PVC', 'NNP'), ('Tubes.', 'NNP'), ('Fits', 'NNP'), ('in', 'IN'), ('your', 'PRP$'), ('space', 'NN'), ('fits', 'NNS'), ('on', 'IN'), ('your', 'PRP$'), ('budget', 'NN'), ('Features', 'NNS'), ('cpu', 'VBP'), ('storage', 'NN'), ('shelf', 'NN'), ('elevated', 'VBD'), ('shelf', 'NN'), ('for', 'IN'), ('a', 'DT'), ('compact', 'JJ'), ('printer', 'NN'), ('or', 'CC'), ('other', 'JJ'), ('stationery', 'NN'), ('decor.', 'NN'), ('Sturdy', 'NNP'), ('on', 'IN'), ('flat', 'JJ'), ('surface', 'NN'), ('Some', 'DT'), ('assembly', 'NN'), ('required', 'VBN'), ('Please', 'NNP'), ('see', 'VB'), ('instruction.', 'JJ'), ('Product', 'NNP'), ('Dimension', 'NNP'), ('39.6', 'CD'), ('W', 'NNP'), ('x15.5', 'NN'), ('D', 'NNP'), ('x33.6', 'NN'), ('H', 'NN ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../data/data-table-2017-06-23T03-23.csv')
missing= df['Features'].isnull()
modern= df['Features'].str.contains('formal',case=False)
df[~missing & modern]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ASIN, Brand, Color, Features, Height, ImageURL, Keyword, Length, Price, Similars, Title, Weight, Width]
# Index: []
